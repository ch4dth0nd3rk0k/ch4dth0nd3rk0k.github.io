# %% [raw]
# ---
# layout: article
# title: TL;DR Dating Profile
# custom_css: article.css
# include_mathjax: false
# ---

# %%
# get libs
import base64
import io
from PIL import Image
import matplotlib.pyplot as plt

# set the style to a dark theme
plt.style.use("dark_background")

# match website background
plt.rcParams["figure.facecolor"] = "#181818"
plt.rcParams["axes.facecolor"] = "#181818"
plt.rcParams["axes.edgecolor"] = "#181818"

# store selfie
challenger_image = (
    "..."
)

# decode the base64 string into binary image data
image_data = base64.b64decode(challenger_image)

# convert binary data to a PIL Image
image = Image.open(io.BytesIO(image_data))

# display the image using matplotlib
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# ## What I Offer
# <br>
#
# + **Dominant Leadership**: A strong, decisive, and primal presence
# <br><br>
#
# + **Monogamy & Loyalty**: A structured, exclusive connection built on trust
# <br><br>
#
# + **Guidance & Mentorship**: Wisdom, strategy, and unwavering support
# <br>
#
# + **Raw Intensity**: No filters, no weakness, just unapologetic masculinity
# <br>
#
# + **Depth & Connection**: A dynamic that blends power with real emotional presence
# <br>
#
# + **Discipline & Structure**: A results-driven, no-nonsense approach to life and relationships
# <br>
#
# + **Survival & Competence**: Rugged capability in all aspects of life
# <br>
#
# + **Submission Fulfillment**: The ability to push limits, create structure, and bring out your deepest desires within a
#   dynamic of trust and control

# %% [markdown]
# ## Next Steps
# To proceed, **you must fill out the [contact form](https://chadthunderkok.com/dating-contact/)**. No form, no response—simple as that. Thank you for your time, and best of luck in your search.
